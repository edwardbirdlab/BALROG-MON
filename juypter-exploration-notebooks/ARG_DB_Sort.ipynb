# %%
## Def to put in a module
import json
import pandas as pd

def import_card_fasta(path):
    f = open('ARG_Databases/card_DB/card.json')
    data = json.load(f)
    Card_Dataframe = pd.DataFrame(data)
    Card_Dataframe = Card_Dataframe.transpose()
    return Card_Dataframe

# %%
Card_Dataframe = import_card_fasta('ARG_Databases/card_DB/card.json')

# %%
Card_Dataframe.loc[Card_Dataframe['model_type'] == 'efflux pump system meta-model']
# Out:
#      model_id                                         model_name  \
# 2713     2713                                              MexXY
# 2705     2705  MexEF-OprN with MexS mutations conferring resi...
# 2682     2682  MexAB-OprM with NalC mutations conferring resi...
# 2680     2680  MexAB-OprM with prematurely terminated MexR co...
# 2686     2686  MexAB-OprM with CpxR regulator conferring resi...
# 2707     2707  MexEF-OprN with MvaT deletion conferring resis...
# 2679     2679  MexAB-OprM with MexR mutations confers resista...
# 2695     2695               MexCD-OprJ with type B NfxB mutation
# 2711     2711                                         MexXY-OprM
# 2712     2712                                         MexXY-OprA
# 2724     2724                                        MuxABC-OpmB
# 2729     2729                                         MexJK-OprM
# 2731     2731                                         MexJK-OpmH
# ...

# %%
Card_Dataframe.loc[Card_Dataframe['ARO_accession'] == '3003032']['model_description'][0]
# Out:
# C:\Users\edwardbird\AppData\Local\Temp\ipykernel_26452\2814646460.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Card_Dataframe.loc[Card_Dataframe['ARO_accession'] == '3003032']['model_description'][0]
# 'Efflux Pump System Meta-Models (EPS) are dedicated to efflux complexes and their regulators, such as AcrAB-TolC. Using the efflux pump components parameter, this model type simply includes a list of detection models for each component of the complex. This model type is still under development and not currently supported by the Resistance Gene Identifier (RGI) software.'

# %%
Card_Dataframe.loc[Card_Dataframe['model_type_id'] == '40326']['model_description'][0]
# Out:
# C:\Users\edwardbird\AppData\Local\Temp\ipykernel_26452\1589304036.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Card_Dataframe.loc[Card_Dataframe['model_type_id'] == '40326']['model_description'][0]
# "Protein Domain Meta-Models (PDMs) are dedicated to AMR fusion proteins, e.g. AAC(3)-Ib/AAC(6')-Ib''. The individual domains will have their own individual detection models (e.g. PHM, PVM, POM, etc.) while the PDM checks to see if all the component domiains of the fusion protein have a Strict or Perfect hit and are ordered correctly within the gene. This model type is still under development and not currently supported by the Resistance Gene Identifier (RGI) software."

# %%
Card_Dataframe['model_type'].unique()
# Out:
# array(['protein homolog model', 'protein overexpression model',
#        'protein variant model', 'rRNA gene variant model',
#        'gene cluster meta-model', 'protein domain meta-model',
#        'protein knockout model', 'efflux pump system meta-model', '3.2.8',
#        nan, '2023-10-02T18:08:58+00:00'], dtype=object)
